# %%
# 인구 피라미드
import pandas as pd
file_name = '201204_201204_연령별인구현황_월간.xlsx'
df_m = pd.read_excel(file_name,skiprows=3, index_col='행정기관',usecols='B,E:Y') #usecols 칼럼 부분 가져오기
df_m.head(3)
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#               0~4세       5~9세     10~14세     15~19세     20~24세     25~29세  \
# 행정기관
# 전국       1,197,688  1,208,960  1,605,875  1,870,484  1,706,180  1,768,828
# 서울특별시      216,587    210,844    278,066    341,737    340,551    415,576
# 부산광역시       67,859     68,658     98,161    127,492    124,296    123,555
#
#             30~34세     35~39세     40~44세     45~49세  ...     55~59세  \
# 행정기관                                                 ...
# 전국       2,069,599  2,132,057  2,344,278  2,179,233  ...  1,626,953
# 서울특별시      477,232    447,681    463,024    412,712  ...    336,015
# 부산광역시      139,360    133,097    147,961    144,745  ...    138,505
#
#             60~64세   65~69세   70~74세   75~79세   80~84세  85~89세  90~94세 95~99세  \
# 행정기관
# ...

# %%
df_m.iloc[0] = df_m.iloc[0].str.replace(',','').astype(int) #1,1197,688 -> 1197699 정수형으로 변경

# %%
df_m.iloc[0]
# Out:
# 0~4세        764015
# 5~9세       1121950
# 10~14세     1218138
# 15~19세     1205908
# 20~24세     1594771
# 25~29세     1855190
# 30~34세     1693246
# 35~39세     1754707
# 40~44세     2046306
# 45~49세     2095233
# 50~54세     2282218
# 55~59세     2090815
# 60~64세     2060563
# 65~69세     1489753
# 70~74세     1002998
# 75~79세      704313
# 80~84세      475312
# 85~89세      203351
# 90~94세       51561
# 95~99세        9232
# 100세 이상       1473
# Name: 전국  , dtype: object

# %%
# 여자데이터 정의

import pandas as pd
df_w = pd.read_excel(file_name,skiprows=3, index_col='행정기관',usecols='B,AB:AV') #usecols 칼럼 부분 가져오기
df_w.head(3)
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#           0~4세.1     5~9세.1   10~14세.1   15~19세.1   20~24세.1   25~29세.1  \
# 행정기관
# 전국       725,453  1,068,474  1,149,761  1,123,448  1,469,753  1,659,793
# 서울특별시    115,166    162,430    178,271    190,171    316,267    419,790
# 부산광역시     41,508     63,294     65,217     63,633     93,028    104,101
#
#           30~34세.1   35~39세.1   40~44세.1   45~49세.1  ...   55~59세.1  \
# 행정기관                                                 ...
# 전국       1,549,552  1,669,206  1,978,366  2,033,944  ...  2,040,121
# 서울특별시      371,298    345,322    370,366    374,440  ...    358,590
# 부산광역시       94,756    100,765    123,669    124,437  ...    139,382
#
#           60~64세.1   65~69세.1   70~74세.1 75~79세.1 80~84세.1 85~89세.1 90~94세.1  \
# 행정기관
# ...

# %%
df_m.columns
# Out:
# Index(['0~4세', '5~9세', '10~14세', '15~19세', '20~24세', '25~29세', '30~34세',
#        '35~39세', '40~44세', '45~49세', '50~54세', '55~59세', '60~64세', '65~69세',
#        '70~74세', '75~79세', '80~84세', '85~89세', '90~94세', '95~99세', '100세 이상'],
#       dtype='object')

# %%
df_w.columns
# Out:
# Index(['0~4세.1', '5~9세.1', '10~14세.1', '15~19세.1', '20~24세.1', '25~29세.1',
#        '30~34세.1', '35~39세.1', '40~44세.1', '45~49세.1', '50~54세.1', '55~59세.1',
#        '60~64세.1', '65~69세.1', '70~74세.1', '75~79세.1', '80~84세.1', '85~89세.1',
#        '90~94세.1', '95~99세.1', '100세 이상.1'],
#       dtype='object')

# %%
df_w.columns = df_m.columns #컬럼명 통일
df_w.columns
# Out:
# Index(['0~4세', '5~9세', '10~14세', '15~19세', '20~24세', '25~29세', '30~34세',
#        '35~39세', '40~44세', '45~49세', '50~54세', '55~59세', '60~64세', '65~69세',
#        '70~74세', '75~79세', '80~84세', '85~89세', '90~94세', '95~99세', '100세 이상'],
#       dtype='object')

# %%
df_w.iloc[0] = df_w.iloc[0].str.replace(',','').astype(int) #1,1197,688 -> 1197699 정수형으로 변경
df_w
# Out:
#               0~4세     5~9세   10~14세   15~19세   20~24세   25~29세   30~34세  \
# 행정기관
# 전국          725453  1068474  1149761  1123448  1469753  1659793  1549552
# 서울특별시      115,166  162,430  178,271  190,171  316,267  419,790  371,298
# 부산광역시       41,508   63,294   65,217   63,633   93,028  104,101   94,756
# 대구광역시       31,348   48,793   51,979   52,850   69,851   73,006   63,573
# 인천광역시       42,240   61,978   66,866   64,745   84,237  100,749   94,288
# 광주광역시       21,613   32,626   36,191   36,781   48,377   49,041   41,206
# 대전광역시       20,723   30,683   33,516   34,516   47,812   50,829   43,836
# 울산광역시       17,150   26,353   27,307   24,598   28,183   30,645   30,530
# 세종특별자치시      9,760   13,275   13,206   10,092    8,545   10,465   14,038
# 경기도        215,418  311,818  329,542  313,037  395,512  445,443  433,866
# 강원도         20,463   28,069   31,489   32,342   38,599   37,338   35,771
# 충청북도        22,859   33,085   35,746   34,529   41,562   43,732   40,649
# ...

# %%
# 데이터 시각화

# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic' # Windows
# matplotlib.rcParams['font.family'] = 'AppleGothic' # Mac
matplotlib.rcParams['font.size'] = 15 # 글자 크기
matplotlib.rcParams['axes.unicode_minus'] = False # 한글 폰트 사용 시, 마이너스 글자가 깨지는 현상을 해결

# %%
plt.figure(figsize=(10,7))
plt.barh(df_m.columns, -df_m.iloc[0]/ 1000) #단위 : 천명
plt.barh(df_w.columns, df_w.iloc[0] //1000)
plt.title("2012 대한민국 인구 피라미드")
plt.savefig("2012_인구피라미드.png",dpi=100) #파일로저장
plt.show()
